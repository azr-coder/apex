# %%
from openai import OpenAI
import os

client = OpenAI(
    # 如果没有配置环境变量，请用阿里云百炼API Key替换：api_key="sk-xxx"
    api_key="sk-8b9aa0e5c42a4cee9b6c593a9d07f1bf",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

messages = [{"role": "user", "content": "你是谁"}]
completion = client.chat.completions.create(
    model="qwen3.5-plus",  # 您可以按需更换为其它深度思考模型
    messages=messages,
    extra_body={"enable_thinking": True},
    stream=True
)
is_answering = False  # 是否进入回复阶段
print("\n" + "=" * 20 + "思考过程" + "=" * 20)
for chunk in completion:
    delta = chunk.choices[0].delta
    if hasattr(delta, "reasoning_content") and delta.reasoning_content is not None:
        if not is_answering:
            print(delta.reasoning_content, end="", flush=True)
    if hasattr(delta, "content") and delta.content:
        if not is_answering:
            print("\n" + "=" * 20 + "完整回复" + "=" * 20)
            is_answering = True
        print(delta.content, end="", flush=True)
# Out:
# ====================思考过程====================
# 好的，用户问“你是谁”，我需要先确认自己的身份。我是 Qwen3.5，是阿里巴巴最新推出的通义千问大语言模型。我应该简洁明了地介绍自己，同时突出关键升级点，但避免过于技术化。
#
# 首先，用户可能想知道我的基本身份，所以开头要说明我是 Qwen3.5，属于通义千问系列。然后需要提到我的主要能力，比如多语言支持、上下文处理、推理能力等。但要注意不要罗列太多技术参数，以免让用户感到困惑。
#
# 用户可能没有说出深层需求，他们可能想了解我能帮他们做什么，或者我和其他模型有什么不同。所以需要强调实际应用，比如处理复杂任务、多语言交流、代码生成等。同时，保持友好和简洁，避免信息过载。
#
# 需要检查是否有遗漏的重要点，比如上下文窗口是 256K，支持 100 多种语言，知识截止到 2026 年。这些关键数据要准确。另外，提到架构升级，比如混合注意力机制，但不用深入技术细节，而是说明带来的好处，比如更快更准。
#
# 还要注意语气亲切，用口语化的中文，避免太正式。可能用户是第一次接触，需要让他们感到容易理解。最后，邀请用户提问或给出任务，促进互动。
#
# 需要避免错误，比如不要混淆 Qwen3 和 Qwen3.5 的区别，确保提到的升级点正确。比如逻辑推理、视觉分析、智能体规划这些是 3.5 的改进点。同时，不要夸大能力，保持诚实，比如提到在医疗法律领域的专业性提升，但不过度承诺。
#
# 总结下来，结构应该是：自我介绍，关键能力简述，应用场景，邀请互动。保持简短，重点突出，让用户快速了解我能做什么，并愿意进一步交流。
# ====================完整回复====================
# 你好！我是 **Qwen3.5**，阿里巴巴最新推出的通义千问大语言模型。我基于更全面的知识语料训练，具备以下核心能力：
#
# - 🌍 **多语言支持**：流畅处理 100+ 种语言，包括中文、英语、小语种等；
# - 📚 **超长上下文**：原生支持 256K tokens，可精准理解长篇文档、复杂图表或跨段落逻辑；
# - 🧠 **深度推理**：在数学、科学、代码生成等领域经过专项优化，能拆解多步骤任务；
# - 👁️ **视觉解析**：可分析图表、公式、科学图示，并梳理因果关系；
# - ⚙️ **智能体协作**：支持自主规划任务、调用工具，甚至完成多轮搜索与执行；
# - 💻 **全栈代码**：从生成、调试到部署，支持主流编程语言，还能将创意转化为可运行页面。
#
# 我的知识截止时间为 **2026 年**，在医疗、法律等垂直领域也经过专业对齐。需要我帮你写代码、分析数据、创作内容，还是解答专业问题？随时告诉我！ 😊
